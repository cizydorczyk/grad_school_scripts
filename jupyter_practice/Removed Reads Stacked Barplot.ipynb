# %%
data = read.table("/Users/conradizydorczyk/grad_school_data/primary_project/bioinformatics_meeting_update_1/reads_removed.txt", header=TRUE, sep="\t")

# %%
str(data)
# Out:
# 'data.frame':	203 obs. of  4 variables:
#  $ Isolate.ID    : Factor w/ 203 levels "10","14","152",..: 1 2 3 4 5 6 8 7 9 11 ...
#  $ Trimmomatic.V1: int  2817942 2299584 2845088 2060374 2497192 2596918 2648498 4728594 2780484 2764176 ...
#  $ Trimmomatic.V2: int  2725554 2211652 2737626 1974500 2407116 2492980 2546372 4541064 2677702 2655614 ...
#  $ Trimmomatic.V3: int  2188290 1696202 2125002 1467514 1872342 1886944 1928368 3416902 2066272 1977646 ...

# %%
str(data)
# Out:
# 'data.frame':	203 obs. of  4 variables:
#  $ Isolate.ID    : Factor w/ 203 levels "10","14","152",..: 1 2 3 4 5 6 8 7 9 11 ...
#  $ Trimmomatic.V1: int  2817942 2299584 2845088 2060374 2497192 2596918 2648498 4728594 2780484 2764176 ...
#  $ Trimmomatic.V2: int  2725554 2211652 2737626 1974500 2407116 2492980 2546372 4541064 2677702 2655614 ...
#  $ Trimmomatic.V3: int  2188290 1696202 2125002 1467514 1872342 1886944 1928368 3416902 2066272 1977646 ...

# %%
data=read.table("/Users/conradizydorczyk/grad_school_data/primary_project/bioinformatics_meeting_update_1/reads_removed_transposed.txt", header=TRUE, sep="\t")
# Out:
# Warning message in read.table("/Users/conradizydorczyk/grad_school_data/primary_project/bioinformatics_meeting_update_1/reads_removed_transposed.txt", :
# “incomplete final line found by readTableHeader on '/Users/conradizydorczyk/grad_school_data/primary_project/bioinformatics_meeting_update_1/reads_removed_transposed.txt'”

# %%
data
# Out:
#   Isolate.ID     X6      X7      X8      X10     X14     X17     X19
# 1 Trimmomatic V1 2876048 2513704 2026060 2817942 2299584 2497192 4728594
# 2 Trimmomatic V2 2786078 2403972 1955634 2725554 2211652 2407116 4541064
# 3 Trimmomatic V3 2288352 1711766 1533882 2188290 1696202 1872342 3416902
#   X21     X23     ⋯ X553.2 X556.1  X556.2  X559.1  X559.2  X572.1  X573.2
# 1 4514460 6020804 ⋯ 923212 2672876 2060740 3784266 3928756 5100776 3587934
# 2 4335554 5785556 ⋯ 881572 2565362 1975982 3659752 3795226 4920138 3478258
# 3 3236162 4425612 ⋯ 619870 1882150 1428204 2950452 2991150 3808194 2817902
#   X573.3  X579.1  X579.2
# 1 3611714 5990010 4946254
# 2 3489012 5759694 4767672
# 3 2748570 4341362 3708842

# %%
barplot(as.matrix(data))
# Out:
# Warning message in apply(height, 2L, cumsum):
# “NAs introduced by coercion”
# plot without title

# %%
# Out:
# Warning message in read.table("/Users/conradizydorczyk/grad_school_data/primary_project/bioinformatics_meeting_update_1/reads_removed_transposed.txt", :
# “incomplete final line found by readTableHeader on '/Users/conradizydorczyk/grad_school_data/primary_project/bioinformatics_meeting_update_1/reads_removed_transposed.txt'”

# %%
data=read.table("/Users/conradizydorczyk/grad_school_data/primary_project/bioinformatics_meeting_update_1/reads_removed_transposed.txt", header=TRUE, sep="\t")

# %%
data
# Out:
#   Isolate.ID     X6      X7      X8      X10     X14     X17     X19
# 1 Trimmomatic V1 2876048 2513704 2026060 2817942 2299584 2497192 4728594
# 2 Trimmomatic V2 2786078 2403972 1955634 2725554 2211652 2407116 4541064
# 3 Trimmomatic V3 2288352 1711766 1533882 2188290 1696202 1872342 3416902
#   X21     X23     ⋯ X553.2 X556.1  X556.2  X559.1  X559.2  X572.1  X573.2
# 1 4514460 6020804 ⋯ 923212 2672876 2060740 3784266 3928756 5100776 3587934
# 2 4335554 5785556 ⋯ 881572 2565362 1975982 3659752 3795226 4920138 3478258
# 3 3236162 4425612 ⋯ 619870 1882150 1428204 2950452 2991150 3808194 2817902
#   X573.3  X579.1  X579.2
# 1 3611714 5990010 4946254
# 2 3489012 5759694 4767672
# 3 2748570 4341362 3708842

# %%
barplot(as.matrix(data))
# Out:
# Warning message in apply(height, 2L, cumsum):
# “NAs introduced by coercion”
# plot without title

# %%
data = read.table("/Users/conradizydorczyk/grad_school_data/primary_project/bioinformatics_meeting_update_1/reads_removed_transposed_percent.txt", header=TRUE, sep="\t")

# %%
data
# Out:
#   X10       X14       X152      X160      X17       X180     X196
# 1 77.655608 73.761254 74.690203 71.225612 74.977895 72.66090 72.809872
# 2 19.065829 22.414924 21.532691 24.606503 21.415013 23.33674 23.334131
# 3  3.278563  3.823822  3.777106  4.167884  3.607091  4.00236  3.855997
#   X19       X200      X217      ⋯ X579.1    X579.2    X580      X581
# 1 72.260422 74.313393 71.545589 ⋯ 72.476707 74.982846 68.361324 73.695630
# 2 23.773705 21.990056 24.526948 ⋯ 23.678291 21.406705 27.216030 22.798352
# 3  3.965872  3.696551  3.927463 ⋯  3.845002  3.610449  4.422646  3.506018
#   X582      X583     X6        X7        X8        X97
# 1 71.626031 71.33789 79.565849 68.097358 75.707630 72.722513
# 2 24.091030 24.73977 17.305900 27.537292 20.816363 23.488404
# 3  4.282939  3.92234  3.128251  4.365351  3.476008  3.789083

# %%
barplot(as.matrix(data))
# Out:
# plot without title
