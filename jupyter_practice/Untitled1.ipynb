# %%
data=read.table("/home/conrad/Data/primary_project_2/de_novo_assemblies/E9_assemblies/E9_assembly_stats_F22/303_R1_assembly.txt", header=TRUE, sep="\t")
plot(log10(data$consensus_length), log10(data$average_coverage), pch=21, cex=0.8, xlab="Contig Length (log)", ylab="Contig Coverage (log)", las=1, main="Isolate 303")
# Out:
# Plot with title “Isolate 303”
